# %%
def duplicate(in_path, out_path, count):
    with open(in_path, "rb") as f:
        data = f.read()
    
    with open(out_path, "wb") as f:
        for _ in range(count):
            f.write(data)

# %%
duplicate("measurements beeg.000", "200x.000", 200)
