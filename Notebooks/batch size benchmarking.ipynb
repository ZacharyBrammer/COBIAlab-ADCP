# %%
import psutil
mem = psutil.virtual_memory().available
target_mb = 10
batch_size = min(4096, max(256, target_mb * 1024**2 // 2070))
batch_size
# Out:
# 4096

# %%
from decode_bin import decode_bin
import timeit

# %%
t512 = timeit.Timer('decode_bin.decode_bin("measurements.000", 512)', "import decode_bin")
t1024 = timeit.Timer('decode_bin.decode_bin("measurements.000", 1024)', "import decode_bin")
t2048 = timeit.Timer('decode_bin.decode_bin("measurements.000", 2048)', "import decode_bin")
t4096 = timeit.Timer('decode_bin.decode_bin("measurements.000", 4096)', "import decode_bin")
t4096 = timeit.Timer('decode_bin.decode_bin("measurements.000", 4096)', "import decode_bin")
t8162 = timeit.Timer('decode_bin.decode_bin("measurements.000", 8162)', "import decode_bin")
t16384 = timeit.Timer('decode_bin.decode_bin("measurements.000", 16384)', "import decode_bin")
t32768 = timeit.Timer('decode_bin.decode_bin("measurements.000", 32768)', "import decode_bin")

# %%
t512.timeit(number=1000) / 1000
# Out:
# 0.5235780086139998

# %%
t1024.timeit(number=1000) / 1000
# Out:
# 0.3730153316659998

# %%
t2048.timeit(number=1000) / 1000
# Out:
# 0.3355629687400001

# %%
t4096.timeit(number=1000) / 1000
# Out:
# 0.29915966147300016

# %%
t8162.timeit(number=1000) / 1000
# Out:
# 0.267158452871

# %%
t16384.timeit(number=1000) / 1000
# Out:
# 0.2704559265580001

# %%
t32768.timeit(number=1000) / 1000
# Out:
# 0.27312298052500045

# %%
t256 = timeit.Timer('decode_bin.decode_bin("measurements.000", 256)', "import decode_bin")
t256.timeit(number=10) / 10
# Out:
# 0.9716493468000408
